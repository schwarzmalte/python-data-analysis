# %%
import matplotlib.pyplot as plt

# %%
#enable import of my packages in the src folder
import sys
sys.path.append('../..')

# %%
#import my package of interes
from src.ISOM_tools.measurements.bright_IV import bright_IV_prep

# %%
#test functions
file = '2159_MS48_H1_AM1.5G_293K.dat'
data = bright_IV_prep(file,214E-6)
#print(data)

# %%
plt.plot(data['data']['V'],-data['data']['J'])
